# %%
# ===================================================================================================
# PROBLEM B4
#
# Build and train a classifier for the BBC-text dataset.
# This is a multiclass classification problem.
# Do not use lambda layers in your model.
#
# The dataset used in this problem is originally published in: http://mlg.ucd.ie/datasets/bbc.html.
#
# Desired accuracy and validation_accuracy > 91%
# ===================================================================================================

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
def train_val_split(sentences, labels, training_split):
    # Compute the number of sentences that will be used for training (should be an integer)
    train_size = int(len(sentences) * training_split)

    # Split the sentences and labels into train/validation splits
    train_sentences = sentences[0:train_size]
    train_labels = labels[0:train_size]

    validation_sentences = sentences[train_size:]
    validation_labels = labels[train_size:]

    return train_sentences, validation_sentences, train_labels, validation_labels

# %%
def tokenize_labels(all_labels, split_labels):
    # Instantiate the Tokenizer (no additional arguments needed)
    label_tokenizer = Tokenizer()

    # Fit the tokenizer on all the labels
    label_tokenizer.fit_on_texts(all_labels)

    # Convert labels to sequences
    label_seq = label_tokenizer.texts_to_sequences(split_labels)

    # Convert sequences to a numpy array. Don't forget to substact 1 from every entry in the array!
    label_seq_np = np.array(label_tokenizer.texts_to_sequences(split_labels)) - 1

    return label_seq_np

# %%
def solution_B4():
    bbc = pd.read_csv(
        'https://github.com/dicodingacademy/assets/raw/main/Simulation/machine_learning/bbc-text.csv')

    # DO NOT CHANGE THIS CODE
    # Make sure you used all of these parameters or you can not pass this test
    vocab_size = 1000
    embedding_dim = 16
    max_length = 120
    trunc_type = 'post'
    padding_type = 'post'
    oov_tok = "<OOV>"
    training_portion = 0.8

    # YOUR CODE HERE
    bbc_texts, bbc_labels = bbc['text'], bbc['category']
    np_labels = np.array(bbc_labels)
    # Using "shuffle=False"
    training_sentences, testing_sentences, training_labels, testing_labels = train_test_split(bbc_texts, bbc_labels, test_size = 1.0 - training_portion, shuffle=False)

    # Fit your tokenizer with training data
    tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
    tokenizer.fit_on_texts(training_sentences)
    word_index = tokenizer.word_index

    sequences = tokenizer.texts_to_sequences(training_sentences)

    testing_sequences = tokenizer.texts_to_sequences(testing_sentences)

    padded = pad_sequences(sequences, maxlen = max_length, truncating = trunc_type, padding = padding_type)

    testing_padded = pad_sequences(testing_sequences, maxlen = max_length, truncating = trunc_type, padding = padding_type)

    train_label_seq = tokenize_labels(bbc_labels, training_labels)
    test_label_seq = tokenize_labels(bbc_labels, testing_labels)

    model = tf.keras.Sequential([
        # YOUR CODE HERE.
        tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length = max_length),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(24, activation='relu'),
        # YOUR CODE HERE. DO not change the last layer or test may fail
        tf.keras.layers.Dense(6, activation='softmax')
    ])




    # Make sure you are using "sparse_categorical_crossentropy" as a loss fuction
    model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
    model.fit(padded, train_label_seq, epochs=50, batch_size=32, verbose = 1, validation_data=(testing_padded, test_label_seq))

    return model

    # The code below is to save your model as a .h5 file.
    # It will be saved automatically in your Submission folder.

# %%
if __name__ == '__main__':
    # DO NOT CHANGE THIS CODE
    model = solution_B4()
    model.save("model_B4.h5")
# Out:
# Epoch 1/50
# 56/56 [==============================] - 1s 6ms/step - loss: 1.7599 - accuracy: 0.2815 - val_loss: 1.7198 - val_accuracy: 0.2697
# Epoch 2/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.6755 - accuracy: 0.2921 - val_loss: 1.6291 - val_accuracy: 0.2787
# Epoch 3/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.5843 - accuracy: 0.3163 - val_loss: 1.5411 - val_accuracy: 0.3348
# Epoch 4/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.4820 - accuracy: 0.4169 - val_loss: 1.4333 - val_accuracy: 0.5326
# Epoch 5/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.3499 - accuracy: 0.5494 - val_loss: 1.2919 - val_accuracy: 0.5865
# Epoch 6/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.1851 - accuracy: 0.6657 - val_loss: 1.1299 - val_accuracy: 0.7596
# Epoch 7/50
# 56/56 [==============================] - 0s 3ms/step - loss: 1.0124 - accuracy: 0.8163 - val_loss: 0.9798 - val_accuracy: 0.8112
# Epoch 8/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.8506 - accuracy: 0.8730 - val_loss: 0.8297 - val_accuracy: 0.8697
# Epoch 9/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.6984 - accuracy: 0.9112 - val_loss: 0.6985 - val_accuracy: 0.8831
# Epoch 10/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.5706 - accuracy: 0.9242 - val_loss: 0.5966 - val_accuracy: 0.8921
# Epoch 11/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.4694 - accuracy: 0.9331 - val_loss: 0.5182 - val_accuracy: 0.8899
# Epoch 12/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.3919 - accuracy: 0.9410 - val_loss: 0.4637 - val_accuracy: 0.9101
# Epoch 13/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.3312 - accuracy: 0.9472 - val_loss: 0.4161 - val_accuracy: 0.9101
# Epoch 14/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2845 - accuracy: 0.9517 - val_loss: 0.3787 - val_accuracy: 0.9056
# Epoch 15/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2457 - accuracy: 0.9635 - val_loss: 0.3521 - val_accuracy: 0.9124
# Epoch 16/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.2161 - accuracy: 0.9640 - val_loss: 0.3325 - val_accuracy: 0.9056
# Epoch 17/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1920 - accuracy: 0.9697 - val_loss: 0.3183 - val_accuracy: 0.9236
# Epoch 18/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1714 - accuracy: 0.9736 - val_loss: 0.3010 - val_accuracy: 0.9191
# Epoch 19/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1531 - accuracy: 0.9764 - val_loss: 0.2900 - val_accuracy: 0.9213
# Epoch 20/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1374 - accuracy: 0.9787 - val_loss: 0.2825 - val_accuracy: 0.9146
# Epoch 21/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.9815 - val_loss: 0.2733 - val_accuracy: 0.9191
# Epoch 22/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1137 - accuracy: 0.9831 - val_loss: 0.2677 - val_accuracy: 0.9213
# Epoch 23/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.1027 - accuracy: 0.9837 - val_loss: 0.2611 - val_accuracy: 0.9213
# Epoch 24/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0933 - accuracy: 0.9848 - val_loss: 0.2560 - val_accuracy: 0.9236
# Epoch 25/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0850 - accuracy: 0.9882 - val_loss: 0.2531 - val_accuracy: 0.9281
# Epoch 26/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0774 - accuracy: 0.9904 - val_loss: 0.2516 - val_accuracy: 0.9281
# Epoch 27/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0708 - accuracy: 0.9921 - val_loss: 0.2486 - val_accuracy: 0.9258
# Epoch 28/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9933 - val_loss: 0.2496 - val_accuracy: 0.9281
# Epoch 29/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0593 - accuracy: 0.9944 - val_loss: 0.2409 - val_accuracy: 0.9258
# Epoch 30/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9966 - val_loss: 0.2415 - val_accuracy: 0.9281
# Epoch 31/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0499 - accuracy: 0.9972 - val_loss: 0.2383 - val_accuracy: 0.9281
# Epoch 32/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 0.9978 - val_loss: 0.2377 - val_accuracy: 0.9281
# Epoch 33/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.9989 - val_loss: 0.2366 - val_accuracy: 0.9281
# Epoch 34/50
# 56/56 [==============================] - 0s 4ms/step - loss: 0.0384 - accuracy: 0.9989 - val_loss: 0.2362 - val_accuracy: 0.9303
# Epoch 35/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9994 - val_loss: 0.2353 - val_accuracy: 0.9303
# Epoch 36/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.2355 - val_accuracy: 0.9303
# Epoch 37/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.2353 - val_accuracy: 0.9326
# Epoch 38/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.2353 - val_accuracy: 0.9303
# Epoch 39/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9303
# Epoch 40/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9303
# Epoch 41/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.2359 - val_accuracy: 0.9326
# Epoch 42/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.9303
# Epoch 43/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.9281
# Epoch 44/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.2357 - val_accuracy: 0.9281
# Epoch 45/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.2364 - val_accuracy: 0.9281
# Epoch 46/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.2356 - val_accuracy: 0.9303
# Epoch 47/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.2377 - val_accuracy: 0.9303
# Epoch 48/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.2362 - val_accuracy: 0.9281
# Epoch 49/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.2387 - val_accuracy: 0.9303
# Epoch 50/50
# 56/56 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.2386 - val_accuracy: 0.9281
