# %%
# =====================================================================================================
# PROBLEM C4
#
# Build and train a classifier for the sarcasm dataset.
# The classifier should have a final layer with 1 neuron activated by sigmoid.
#
# Do not use lambda layers in your model.
#
# Dataset used in this problem is built by Rishabh Misra (https://rishabhmisra.github.io/publications).
#
# Desired accuracy and validation_accuracy > 75%
# =======================================================================================================

# %%
import json
import tensorflow as tf
import numpy as np
import urllib
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
def solution_C4():
    data_url = 'https://github.com/dicodingacademy/assets/raw/main/Simulation/machine_learning/sarcasm.json'
    urllib.request.urlretrieve(data_url, 'sarcasm.json')

    # DO NOT CHANGE THIS CODE
    # Make sure you used all of these parameters or test may fail
    vocab_size = 1000
    embedding_dim = 16
    max_length = 120
    trunc_type = 'post'
    padding_type = 'post'
    oov_tok = "<OOV>"
    training_size = 20000

    sentences = []
    labels = []

    # YOUR CODE HERE
    with open("sarcasm.json", 'r') as j:
        sarcasm = json.load(j)

    for item in sarcasm:
        sentences.append(item['headline'])
        labels.append(item['is_sarcastic'])

    training_sentences = sentences[0:training_size]
    testing_sentences = sentences[training_size:]
    training_labels = labels[0:training_size]
    testing_labels = labels[training_size:]
    # Fit your tokenizer with training data
    tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
    tokenizer.fit_on_texts(training_sentences) # YOUR CODE HERE
    word_index = tokenizer.word_index

    training_sequences = tokenizer.texts_to_sequences(training_sentences)
    training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

    testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
    testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

    training_padded = np.array(training_padded)
    training_labels = np.array(training_labels)
    testing_padded = np.array(testing_padded)
    testing_labels = np.array(testing_labels)

    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dropout(0.8),
        tf.keras.layers.Dense(6, activation='relu'),
        # YOUR CODE HERE. DO not change the last layer or test may fail
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    model.fit(training_padded, training_labels, epochs=50, validation_data=(testing_padded, testing_labels), verbose=1)

    return model

# %%
# The code below is to save your model as a .h5 file.
# It will be saved automatically in your Submission folder.
if __name__ == '__main__':
    # DO NOT CHANGE THIS CODE
    model = solution_C4()
    model.save("model_C4.h5")
# Out:
# Epoch 1/50
# 625/625 [==============================] - 3s 3ms/step - loss: 0.6858 - accuracy: 0.5602 - val_loss: 0.6834 - val_accuracy: 0.5633
# Epoch 2/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6751 - accuracy: 0.5603 - val_loss: 0.6582 - val_accuracy: 0.5633
# Epoch 3/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6202 - accuracy: 0.6234 - val_loss: 0.5614 - val_accuracy: 0.7064
# Epoch 4/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5463 - accuracy: 0.7451 - val_loss: 0.5044 - val_accuracy: 0.7895
# Epoch 5/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5045 - accuracy: 0.7717 - val_loss: 0.4737 - val_accuracy: 0.7949
# Epoch 6/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4775 - accuracy: 0.7911 - val_loss: 0.4531 - val_accuracy: 0.8006
# Epoch 7/50
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4624 - accuracy: 0.7946 - val_loss: 0.4414 - val_accuracy: 0.8031
# Epoch 8/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4493 - accuracy: 0.8027 - val_loss: 0.4659 - val_accuracy: 0.7840
# Epoch 9/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4389 - accuracy: 0.8063 - val_loss: 0.4251 - val_accuracy: 0.8134
# Epoch 10/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4318 - accuracy: 0.8078 - val_loss: 0.4209 - val_accuracy: 0.8144
# Epoch 11/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4306 - accuracy: 0.8142 - val_loss: 0.4309 - val_accuracy: 0.7992
# Epoch 12/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4214 - accuracy: 0.8151 - val_loss: 0.4192 - val_accuracy: 0.8094
# Epoch 13/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4157 - accuracy: 0.8148 - val_loss: 0.4146 - val_accuracy: 0.8161
# Epoch 14/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4130 - accuracy: 0.8188 - val_loss: 0.4140 - val_accuracy: 0.8153
# Epoch 15/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4107 - accuracy: 0.8192 - val_loss: 0.4117 - val_accuracy: 0.8132
# Epoch 16/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4112 - accuracy: 0.8187 - val_loss: 0.4125 - val_accuracy: 0.8147
# Epoch 17/50
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4054 - accuracy: 0.8217 - val_loss: 0.4097 - val_accuracy: 0.8138
# Epoch 18/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4072 - accuracy: 0.8187 - val_loss: 0.4099 - val_accuracy: 0.8126
# Epoch 19/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4027 - accuracy: 0.8222 - val_loss: 0.4092 - val_accuracy: 0.8123
# Epoch 20/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4053 - accuracy: 0.8217 - val_loss: 0.4144 - val_accuracy: 0.8119
# Epoch 21/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4050 - accuracy: 0.8207 - val_loss: 0.4156 - val_accuracy: 0.8116
# Epoch 22/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4011 - accuracy: 0.8230 - val_loss: 0.4170 - val_accuracy: 0.8117
# Epoch 23/50
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3987 - accuracy: 0.8237 - val_loss: 0.4107 - val_accuracy: 0.8125
# Epoch 24/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4000 - accuracy: 0.8245 - val_loss: 0.4105 - val_accuracy: 0.8126
# Epoch 25/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4020 - accuracy: 0.8241 - val_loss: 0.4118 - val_accuracy: 0.8122
# Epoch 26/50
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8231 - val_loss: 0.4103 - val_accuracy: 0.8119
# Epoch 27/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3955 - accuracy: 0.8281 - val_loss: 0.4102 - val_accuracy: 0.8150
# Epoch 28/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4004 - accuracy: 0.8225 - val_loss: 0.4101 - val_accuracy: 0.8135
# Epoch 29/50
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3972 - accuracy: 0.8239 - val_loss: 0.4168 - val_accuracy: 0.8073
# Epoch 30/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3940 - accuracy: 0.8272 - val_loss: 0.4098 - val_accuracy: 0.8138
# Epoch 31/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3942 - accuracy: 0.8257 - val_loss: 0.4108 - val_accuracy: 0.8129
# Epoch 32/50
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3934 - accuracy: 0.8256 - val_loss: 0.4102 - val_accuracy: 0.8143
# Epoch 33/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3972 - accuracy: 0.8238 - val_loss: 0.4103 - val_accuracy: 0.8147
# Epoch 34/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3959 - accuracy: 0.8263 - val_loss: 0.4122 - val_accuracy: 0.8126
# Epoch 35/50
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3945 - accuracy: 0.8274 - val_loss: 0.4101 - val_accuracy: 0.8143
# Epoch 36/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3928 - accuracy: 0.8288 - val_loss: 0.4150 - val_accuracy: 0.8110
# Epoch 37/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3973 - accuracy: 0.8220 - val_loss: 0.4115 - val_accuracy: 0.8132
# Epoch 38/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3939 - accuracy: 0.8290 - val_loss: 0.4156 - val_accuracy: 0.8103
# Epoch 39/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3965 - accuracy: 0.8235 - val_loss: 0.4136 - val_accuracy: 0.8125
# Epoch 40/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3978 - accuracy: 0.8271 - val_loss: 0.4108 - val_accuracy: 0.8123
# Epoch 41/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3918 - accuracy: 0.8252 - val_loss: 0.4106 - val_accuracy: 0.8134
# Epoch 42/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3930 - accuracy: 0.8275 - val_loss: 0.4135 - val_accuracy: 0.8126
# Epoch 43/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3912 - accuracy: 0.8265 - val_loss: 0.4129 - val_accuracy: 0.8131
# Epoch 44/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3920 - accuracy: 0.8278 - val_loss: 0.4126 - val_accuracy: 0.8138
# Epoch 45/50
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3933 - accuracy: 0.8276 - val_loss: 0.4151 - val_accuracy: 0.8128
# Epoch 46/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3893 - accuracy: 0.8288 - val_loss: 0.4122 - val_accuracy: 0.8137
# Epoch 47/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3944 - accuracy: 0.8243 - val_loss: 0.4112 - val_accuracy: 0.8123
# Epoch 48/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3875 - accuracy: 0.8277 - val_loss: 0.4123 - val_accuracy: 0.8140
# Epoch 49/50
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3939 - accuracy: 0.8278 - val_loss: 0.4151 - val_accuracy: 0.8113
# Epoch 50/50
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3891 - accuracy: 0.8266 - val_loss: 0.4118 - val_accuracy: 0.8137
